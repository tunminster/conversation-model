# %% [markdown]
# <a href="https://colab.research.google.com/github/tunminster/conversation-model/blob/master/banking_conversation_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers huggingface_hub

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_id = "mistralai/Mistral-Nemo-Instruct-2407"
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Save the model and tokenizer locally
model.save_pretrained('./users/tunhein/TunHein/projects/banking-conversation-model')
tokenizer.save_pretrained('./users/tunhein/TunHein/projects/banking-conversation-model')
# Out:
# ...
# model-00004-of-00005.safetensors:  18%|#8        | 891M/4.91G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/4.91G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
